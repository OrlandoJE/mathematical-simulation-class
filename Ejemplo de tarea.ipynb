# %% [markdown]
# **Nombre:** Carlos Augusto Arellano Muro
#
# **Edad:** 34
#
# **Carrera:** Etc...
#
# **Intereses:**
# * interés 1
# * etc...

# %% [markdown]
# # Resumen
# Para cambiar una celda de código a Markdown: `Ctrl`+`M`, `M`
#
# [texto del enlace](https://)
