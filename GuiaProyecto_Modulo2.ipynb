# %% [markdown]
# <img style="float: right; margin: 0px 0px 15px 15px;" src="https://upload.wikimedia.org/wikipedia/commons/b/b6/Proyecto_en_construccion.jpg" width="300px" height="200px" />
#
#
# # Guía para presentación de proyectos.
# > Se especifican los componentes básicos que deberá tener cada proyecto. El proyecto debe ser un problema que se pueda modelar con las herramientas vistas en el módulo. En el caso del segundo módulo, métodos heurísticos.

# %% [markdown]
# ___
# ## Especificaciones
#
#  1. Elegir, de nuevo, integrantes para proyecto. Mínimo 2, máximo 3. Pueden ser los mismos.
#  2. Deben elegir un tema para proyecto que se pueda resolver como un problema de métodos heurísticos (Montecarlo).
#  3. Debe contener
#   * Titulo
#   * Objetivos
#   * Modelo
#   * Solución
#   * Conclusiones
#   * Referencias
#
# ### Entregable - Notebook de jupyter.
# > Los anteriores numerales los deben desarrollar en un notebook de jupyter y llamarlo de la siguiente manera `ProyectoModulo1_ApellidoN1_ApellidoN2_ApellidoN3`, donde `ApellidoNi` hace referencia al apellido paterno y la inicial del primer nombre del integrante `i`.
#
# ### Presentación.
# > Recuerden que la nota del proyecto es mitad el trabajo, y mitad la presentación. Deben hacer una presentación en power point para presentar el trabajo en clase el día indicado. La presentación, además de llevar todos los componentes básicos descritos en el entregable, debe llevar una tabla de contenido.
# > - **NO DEBE TENER CÓDIGO, PARA ESO ES EL INFORME EN EL NOTEBOOK**
# > - Presentación: 10 minutos.
# > - Seguir estas recomendaciones: https://es.slideshare.net/MeireComputacion/power-point-pautas-para-una-buen-trabajo

# %% [markdown]
# ___
# ## Componentes básicos básicos
#
# ### Título del trabajo.
# > Debe describir el trabajo.
#
# ### Objetivos.
# > - Se refieren a los propósitos por los cuales se hace el trabajo.
# > - Deben ser concretos, evaluables y verificables.
# > - Deben ser escritos en infinitivo.
# > #### Objetivo general.
# >  - Fin último de estudio. Se formula atendiendo el propósito global del trabajo. No presenta detalles.
# >  - Se orienta a la totalidad del trabajo. Tiene que ver con el título del trabajo.
# > #### Objetivos específicos
# >  - De forma detallada describen cada uno de los componentes del trabajo.
# >  - En conjunto garantizan la consecución del objetivo general.
#
# Referencia:
# - https://es.slideshare.net/rosbur/metodologia-objetivos-generales-y-especficos
#
# ### Modelo que representa el problema.
# > - Se debe incluir la función a optimizar y las restricciones (en caso de que existan).
# > - Deducción del modelo. Explicación detallada de las ecuaciones de acuerdo al problema que se quiera resolver o modelo que se quiera representar.
# > - ¿Qué situación representa el modelo? ¿Cuáles son las limitaciones fundamentales?
# > - Significado y valor de los parámetros (constantes que aparezcan en el modelo).
#
# ### Solución del problema de optimización.
# > - Se debe resolver el problema de optimización.
# > - ¿Condujo el algoritmo de optimización a una solución factible?
# > - Visualización de la solución del problema.
# >
# >   Se deben mostrar gráficas y/o tablas que ilustren de forma adecuada los resultados. No olviden etiquetar los ejes y si se tienen varias curvas en una sola gráfica también etiquetarlas (ojo: que las curvas se puedan diferenciar con colores y estilos de línea).
#
# ### Conclusiones.
# > Mucho cuidado, las conclusiones no son cualquier cosa. Se debe concluir respecto a los objetivos planteados de acuerdo a los resultados obtenidos.
#
# ### Referencias.
# > Citar (en formato APA) la bibliografía utilizada.

# %% [markdown]
# ## Ideas de proyectos:
#
# 1. Simulación de escenarios futuros
#       * Con base en los datos extraídos de https://data.worldbank.org/indicator o https://climatereanalyzer.org/clim/t2_daily/
#          + Cálculo de probabilidades de superar 30°C en el siguiente mes.
#          + Cálculo de la probabilidad de superar el 20% de las emisiones de CO2 en el siguiente año.
#       * Desde los datos del Servicio Sismológico Nacional (http://www2.ssn.unam.mx:8080/catalogo/)
#          + Usar un mayor número de localidades en la predicción de magnitudes de sismos.
#          + Simular y calcular las probabilidades de la profundidad dependiendo de la posición.
#
# 2. Simulación de modelos deterministas
#       * De _Métodos numéricos aplicados a la ingeniería_ de Antonio Nieves y Federico Domínguez (2014). [Páginas 586-608](https://elibro-net.ezproxy.iteso.mx/es/lc/iteso/titulos/39455):
#           + Simulación de la cantidad de un líquido en el drenado de un tanque.
#           + Determinación de compuestos disueltos en una mezcla después de un tiempo determinado.
#           + Determinar la velocidad de un proyectil frenado por el viento.
#           + Simulación de un mezclado imperfecto en un reactor continuo de tanque agitado.
#           + Encontrar la curva elástica o deflexión de una viga.
#           + Simulación de un sistema de suspensión.
#       * Simulación de un reactor de lecho fluidizado (Referencia coquette: Kaushal, P., y Abedi, J. (2010). _A simplified model for biomass pyrolysis in a
#     fluidized bed reactor_. Journal of Industrial and Engineering Chemistry, 16 (5),
#     748-755).
#       * Simulación del sistema de levitación magnética: [Librito acá. Parte I, páginas 192-200](https://ocw.mit.edu/courses/res-6-003-electromechanical-dynamics-spring-2009/).
